# %%
pip install cooper-optim
# Out:
# Collecting cooper-optim
#   Downloading cooper_optim-1.0.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: torch>=1.13.1 in /usr/local/lib/python3.12/dist-packages (from cooper-optim) (2.10.0+cpu)
# Requirement already satisfied: typing-extensions>=4.13.0 in /usr/local/lib/python3.12/dist-packages (from cooper-optim) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (3.25.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=1.13.1->cooper-optim) (2025.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.13.1->cooper-optim) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.13.1->cooper-optim) (3.0.3)
# Downloading cooper_optim-1.0.1-py3-none-any.whl (48 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.7/48.7 kB 13.7 kB/s eta 0:00:00
# Installing collected packages: cooper-optim
# Successfully installed cooper-optim-1.0.1

# %%
import numpy as np
import torch
import torch.nn as nn
import cooper
from cooper.penalty_coefficients import MultiplicativePenaltyCoefficientUpdater

# %%
def compute_d(arch):
    d = 0
    for i in range(len(arch) - 1):
        d += arch[i] * arch[i + 1]
    return d

# %%
def unpack_weights(w_flat, arch):
    matrices = []
    idx = 0
    for i in range(len(arch) - 1):
        n_in, n_out = arch[i], arch[i + 1]
        size = n_in * n_out
        W = w_flat[idx: idx + size].reshape(n_out, n_in)
        matrices.append(W)
        idx += size
    return matrices

# %%
def forward_pass(u, w_flat, biases, arch):
    weight_mats = unpack_weights(w_flat, arch)
    a = u
    for l, W in enumerate(weight_mats):
        z = W @ a + biases[l].unsqueeze(1)
        if l < len(weight_mats) - 1:
            a = torch.tanh(z)
        else:
            a = z
    return a

# %%
def binary_entropy(Q, eps=1e-6):
    Qc = Q.clamp(eps, 1 - eps) #
    return -(Qc * Qc.log() + (1 - Qc) * (1 - Qc).log()).sum()

# %%
class SparseNNModel(nn.Module):
    def __init__(self, arch, k, eps=1e-6):
        super().__init__()
        self.arch = arch
        self.k = k
        self.eps = eps
        self.d = compute_d(arch)

        # Q initialized column-stochastic
        Q_init = torch.rand(self.d, k)
        Q_init = Q_init / Q_init.sum(dim=0, keepdim=True)
        self.Q = nn.Parameter(Q_init)

        # reduced coefficients
        self.x_coeff = nn.Parameter(torch.randn(k) * 0.05)

        # biases
        self.biases = nn.ParameterList()
        for i in range(len(arch) - 1):
            self.biases.append(nn.Parameter(torch.zeros(arch[i + 1])))

    def get_w(self):
        return self.Q @ self.x_coeff

    def forward(self, u):
        return forward_pass(u, self.get_w(), self.biases, self.arch)

    def clamp_Q(self):
        with torch.no_grad():
            self.Q.clamp_(self.eps, 1.0 - self.eps) #

# %%
class SparseNNCMP(cooper.ConstrainedMinimizationProblem):
    def __init__(
        self,
        model,
        c0,
        u_data,
        y_data,
        ent_tol=1e-1, # ...
        col_tol=1e-3, # ...
        init_penalty_entropy=1.0, # hyperparameter for entropy penalty
        init_penalty_colsum=5.0, # hyperparameter for column sum penalty
        tol=1e-6,
    ):
        super().__init__()
        self.model = model
        self.c0 = c0
        self.u_data = u_data
        self.y_data = y_data
        self.ent_tol = ent_tol
        self.col_tol = col_tol
        self.penalty_entropy = init_penalty_entropy
        self.penalty_colsum = init_penalty_colsum
        self.tol = tol

        # H(Q) - c0 <= 0
        self.entropy_eq = cooper.Constraint(
            constraint_type=cooper.ConstraintType.INEQUALITY,
            formulation_type=cooper.formulations.AugmentedLagrangian,
            multiplier=cooper.multipliers.DenseMultiplier(num_constraints=1),
            penalty_coefficient=cooper.penalty_coefficients.DensePenaltyCoefficient(
                init=torch.tensor([init_penalty_entropy], dtype=torch.float32)
            ),
        )

        # Q^T 1_d - 1_k - tol <= 0
        self.colsum_eq_upper = cooper.Constraint(
            constraint_type=cooper.ConstraintType.INEQUALITY,
            formulation_type=cooper.formulations.AugmentedLagrangian,
            multiplier=cooper.multipliers.DenseMultiplier(num_constraints=model.k),
            penalty_coefficient=cooper.penalty_coefficients.DensePenaltyCoefficient(
                init=torch.full((model.k,), float(init_penalty_colsum), dtype=torch.float32)
            ),
        )

        # -Q^T 1_d + 1_k - tol <= 0
        self.colsum_eq_lower = cooper.Constraint(
            constraint_type=cooper.ConstraintType.INEQUALITY,
            formulation_type=cooper.formulations.AugmentedLagrangian,
            multiplier=cooper.multipliers.DenseMultiplier(num_constraints=model.k),
            penalty_coefficient=cooper.penalty_coefficients.DensePenaltyCoefficient(
                init=torch.full((model.k,), float(init_penalty_colsum), dtype=torch.float32)
            ),
        )


    def compute_cmp_state(self):
        m = self.u_data.shape[1]
        y_pred = self.model(self.u_data)
        loss = ((self.y_data - y_pred) ** 2).sum() / m

        H = binary_entropy(self.model.Q, eps=self.model.eps)
        entropy_violation = (H - self.c0).reshape(1) # (1,)

        colsum_violation_upper = self.model.Q.sum(dim=0) - 1.0 - self.tol # (20,)
        colsum_violation_lower = 1.0 - self.model.Q.sum(dim=0) - self.tol # (20,)

        return cooper.CMPState(
            loss=loss,
            observed_constraints={
                self.entropy_eq: cooper.ConstraintState(violation=entropy_violation),
                self.colsum_eq_upper: cooper.ConstraintState(violation=colsum_violation_upper),
                self.colsum_eq_lower: cooper.ConstraintState(violation=colsum_violation_lower),
            },
        )

    # Debug function to print column gradient components
    def print_column_gradients(self, rows=[0, 1, 2], cols=[0, 1, 2]):
        model = self.model
        Q = model.Q
        x = model.x_coeff

        # forward loss via explicit w so we can differentiate wrt w later
        m = self.u_data.shape[1]
        w = model.get_w()
        y_pred = forward_pass(self.u_data, w, model.biases, model.arch)
        loss = ((self.y_data - y_pred) ** 2).sum() / m

        # entropy and constraints
        H = binary_entropy(Q, eps=model.eps)
        colsum = Q.sum(dim=0)
        col_violation_upper = colsum - 1.0              # shape (k,)
        col_violation_lower = 1.0 - colsum              # shape (k,)

        # individual gradients
        grad_loss = torch.autograd.grad(loss, Q, retain_graph=True)[0]
        grad_H = torch.autograd.grad(H, Q, retain_graph=True)[0]

        grad_col_up = torch.autograd.grad(col_violation_upper.sum(), Q, retain_graph=True)[0]
        grad_col_lo = torch.autograd.grad(col_violation_lower.sum(), Q, retain_graph=True)[0]

        # print selected entries
        print("\n--- Gradient entries for selected Q[i,j] ---")
        for i in rows:
            for j in cols:
                task = grad_loss[i, j].item()
                ent = grad_H[i, j].item()
                up = grad_col_up[i, j].item()
                lo = grad_col_lo[i, j].item()

                print(
                    f"Q[{i},{j}] | "
                    f"task={task:.4e}, "
                    f"entropy={ent:.4e}, "
                    f"col_up={up:.4e}, "
                    f"col_lo={lo:.4e}"
                )

        # verify task gradient formula g_i * x_j using the same w as above
        g_w = torch.autograd.grad(loss, w, retain_graph=True)[0]

        print("\n--- Check task gradient = g_i * x_j ---")
        for i in rows:
            for j in cols:
                formula_val = (g_w[i] * x[j]).item()
                autodiff_val = grad_loss[i, j].item()
                print(
                    f"Q[{i},{j}] | autodiff={autodiff_val:.4e}, formula={formula_val:.4e}"
                )

        # useful summaries
        print("\n--- Norms ---")
        print("||grad_loss||   =", grad_loss.norm().item())
        print("||grad_entropy||=", grad_H.norm().item())
        print("||grad_col_up|| =", grad_col_up.norm().item())
        print("||grad_col_lo|| =", grad_col_lo.norm().item())

    def print_selected_gradients(self, rows=(50, 56, 111, 114), cols=(0, 1, 2, 3)):
      model = self.model
      Q = model.Q
      m = self.u_data.shape[1]

      w = model.get_w()
      y_pred = forward_pass(self.u_data, w, model.biases, model.arch)
      loss = ((self.y_data - y_pred) ** 2).sum() / m

      H = binary_entropy(Q, eps=model.eps)
      colsum = Q.sum(dim=0)

      ent = H - self.c0
      col_up = colsum - 1.0 - self.col_tol
      col_lo = 1.0 - colsum - self.col_tol

      # Task gradient
      grad_task_Q = torch.autograd.grad(loss, Q, retain_graph=True)[0]

      # Multipliers and penalties
      lam_E = self.entropy_eq.multiplier.weight
      lam_U = self.colsum_eq_upper.multiplier.weight
      lam_L = self.colsum_eq_lower.multiplier.weight

      rho_E = self.entropy_eq.penalty_coefficient.value
      rho_U = self.colsum_eq_upper.penalty_coefficient.value
      rho_L = self.colsum_eq_lower.penalty_coefficient.value

      # AL pieces
      ent_term = (lam_E * ent).sum() + 0.5 * (rho_E * torch.relu(ent) ** 2).sum()
      col_up_term = (lam_U * col_up).sum() + 0.5 * (rho_U * torch.relu(col_up) ** 2).sum()
      col_lo_term = (lam_L * col_lo).sum() + 0.5 * (rho_L * torch.relu(col_lo) ** 2).sum()

      grad_ent_Q = torch.autograd.grad(ent_term, Q, retain_graph=True)[0]
      grad_col_up_Q = torch.autograd.grad(col_up_term, Q, retain_graph=True)[0]
      grad_col_lo_Q = torch.autograd.grad(col_lo_term, Q, retain_graph=True)[0]

      grad_total_Q = grad_task_Q + grad_ent_Q + grad_col_up_Q + grad_col_lo_Q

      print("\n--- Final gradient contributions on Q[i,j] ---")
      print(" entry        task          entropy       col_up        col_lo        total")
      print("----------------------------------------------------------------------------")
      for i in rows:
          for j in cols:
              print(
                  f" Q[{i:3d},{j:2d}]   "
                  f"{grad_task_Q[i,j].item(): .3e}   "
                  f"{grad_ent_Q[i,j].item(): .3e}   "
                  f"{grad_col_up_Q[i,j].item(): .3e}   "
                  f"{grad_col_lo_Q[i,j].item(): .3e}   "
                  f"{grad_total_Q[i,j].item(): .3e}"
              )

      print("\n--- Norms ---")
      print(f"||grad_task_Q||   = {grad_task_Q.norm().item():.6f}")
      print(f"||grad_ent_Q||    = {grad_ent_Q.norm().item():.6f}")
      print(f"||grad_col_up_Q|| = {grad_col_up_Q.norm().item():.6f}")
      print(f"||grad_col_lo_Q|| = {grad_col_lo_Q.norm().item():.6f}")
      print(f"||grad_total_Q||  = {grad_total_Q.norm().item():.6f}")

# %%
# Homotopy Training
def run_homotopy(
    arch,
    u_data,
    y_data,
    k,
    c0_start,
    beta=0.97,
    outer_iters=105,
    inner_iters=300,
    ent_tol=1e-1,
    col_tol=1e-3,
    primal_lr=1e-3, # learning rate
    dual_lr=1e-4, # learning rate
    eps=1e-6,
    penalty_growth=1.2,
    init_penalty_entropy=1.0,
    init_penalty_colsum=5.0,
):
    torch.manual_seed(42)

    d = compute_d(arch)
    print(f"Architecture: {arch}, d={d}, k={k}")
    print(f"c0_start={c0_start:.4f}, beta={beta}, outer={outer_iters}, inner={inner_iters}")

    model = SparseNNModel(arch, k, eps=eps)
    print(f"Initial entropy H(Q) = {binary_entropy(model.Q, eps).item():.4f}")

    # Build CMP
    cmp = SparseNNCMP(
        model=model,
        c0=c0_start,
        u_data=u_data,
        y_data=y_data,
        ent_tol=ent_tol,
        col_tol=col_tol,
        init_penalty_entropy=init_penalty_entropy,
        init_penalty_colsum=init_penalty_colsum,
        tol=eps, # ...

    )

    primal_opt = torch.optim.Adam(model.parameters(), lr=primal_lr)
    dual_opt = torch.optim.SGD(cmp.dual_parameters(), lr=dual_lr, maximize=True) # ...

    cooper_opt = cooper.optim.AlternatingPrimalDualOptimizer(
        cmp=cmp,
        primal_optimizers=primal_opt,
        dual_optimizers=dual_opt,
    )
    entropy_updater = MultiplicativePenaltyCoefficientUpdater(
        growth_factor=penalty_growth,
        violation_tolerance=ent_tol,
        has_restart=True,
        )
    colsum_updater = MultiplicativePenaltyCoefficientUpdater(
        growth_factor=penalty_growth,
        violation_tolerance=col_tol,
        has_restart=False,
    )
    history = []
    c0 = c0_start

    for outer in range(outer_iters):
        cmp.c0 = c0

        roll_out = None
        for _ in range(inner_iters):
            roll_out = cooper_opt.roll()

        model.clamp_Q() # ...

        # column-sum multipliers update
        obs = roll_out.cmp_state.observed_constraints
        entropy_updater.step({
            cmp.entropy_eq: obs[cmp.entropy_eq],
        })

        colsum_updater.step({
            cmp.colsum_eq_upper: obs[cmp.colsum_eq_upper],
            cmp.colsum_eq_lower: obs[cmp.colsum_eq_lower],
        })

        with torch.no_grad(): # memory efficient to compute these values without tracking gradients
            Q_now = model.Q.detach().clone()
            H_val = binary_entropy(Q_now, eps).item()
            colsum_err = (Q_now.sum(dim=0) - 1.0).abs().max().item()
            y_pred = model(u_data)
            loss_val = ((y_data - y_pred) ** 2).sum().item() / u_data.shape[1]
            gap = torch.minimum(Q_now, 1.0 - Q_now).max().item()

            cE = cmp.entropy_eq.penalty_coefficient.value.item()
            cU = cmp.colsum_eq_upper.penalty_coefficient.value
            cL = cmp.colsum_eq_lower.penalty_coefficient.value

        history.append({
          "outer": outer,
          "c0": c0,
          "H": H_val,
          "loss": loss_val,
          "gap": gap,
          "colsum_err": colsum_err,
          "cE": cE,
          "cU_max": cU.max().item(),
          "cU_min": cU.min().item(),
          "cU_mean": cU.mean().item(),
          "cL_max": cL.max().item(),
          "cL_min": cL.min().item(),
          "cL_mean": cL.mean().item(),
      })

        print(f"\n=== After outer iteration {outer} ===")
        print(f"c0 = {c0:.4f}, H(Q) = {H_val:.4f}, loss = {loss_val:.4e}")
        print(f"gap = {gap:.4e}, colsum_err = {colsum_err:.4e}")
        print(
            f"Penalties: "
            f"cE = {cE:.4f}, "
            f"cU[max/min/mean] = {cU.max().item():.4f}/{cU.min().item():.4f}/{cU.mean().item():.4f}, "
            f"cL[max/min/mean] = {cL.max().item():.4f}/{cL.min().item():.4f}/{cL.mean().item():.4f}"
        )

        # print selected gradients
        print(f"\nSelected gradients for outer iteration {outer}:")
        cmp.print_selected_gradients(rows=(50, 56, 111, 114), cols=(0, 1, 2, 3))

        c0 *= beta

    return model, history

# %%
def main():
    np.random.seed(42)

    # Data
    m = 500
    u_np = np.random.uniform(-2, 2, size=(1, m))
    y_np = u_np**3 + u_np**2 + 1.0 + 0.1 * np.random.randn(1, m)

    u_data = torch.tensor(u_np, dtype=torch.float32)
    y_data = torch.tensor(y_np, dtype=torch.float32)

    # Architecture
    arch = [1, 10, 10, 1]
    k = 20
    d = compute_d(arch)
    print(f"d = {d} (should be 120)")

    tmp_model = SparseNNModel(arch, k)
    c0_start = 0.99 * binary_entropy(tmp_model.Q).item()

    del tmp_model # free memory before main optimization
    print(f"Starting c0 = {c0_start:.4f}")

    model, history = run_homotopy(
        arch=arch,
        u_data=u_data,
        y_data=y_data,
        k=k,
        c0_start=c0_start,
        beta=0.97, # ...
        outer_iters=105,
        inner_iters=300,
        primal_lr=1e-3, # ...
        dual_lr=1e-4, # ...
        eps=1e-6, # ...
        ent_tol=1e-1,
        col_tol=1e-3,
        penalty_growth=1.2,
        init_penalty_entropy=1.0, # ...
        init_penalty_colsum=5.0, # ...
    )
    Q_final = model.Q.detach().cpu().numpy()
    x_final = model.x_coeff.detach().cpu().numpy()
    w_final = Q_final @ x_final

    print("\n" + "=" * 60)
    print("FINAL RESULTS")
    print("=" * 60)

    if len(history) > 0:
        print(f"Final Q binary gap: {np.max(np.minimum(Q_final, 1.0 - Q_final)):.6f}")
        print(f"Final colsum error: {np.max(np.abs(Q_final.sum(axis=0) - 1.0)):.6f}")
        print(f"Final entropy H(Q): {binary_entropy(model.Q).item():.6f}")
        print(f"Final loss: {history[-1]['loss']:.6f}")

    print("\nEntries of Q > 0.9:")
    rows, cols = np.where(Q_final > 0.9)
    for r, c in zip(rows, cols):
        print(f"  Q[{r},{c}] = {Q_final[r, c]:.6f}")




if __name__ == "__main__":
    main()
# Out:
# d = 120 (should be 120)
# Starting c0 = 110.7231
# Architecture: [1, 10, 10, 1], d=120, k=20
# c0_start=110.7231, beta=0.97, outer=105, inner=300
# Initial entropy H(Q) = 111.7939
#
# === After outer iteration 0 ===
# c0 = 110.7231, H(Q) = 109.9543, loss = 8.9689e+00
# gap = 8.4777e-02, colsum_err = 2.6528e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 5.0000/5.0000/5.0000
#
# Selected gradients for outer iteration 0:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -2.275e-01    0.000e+00    1.210e+00   -8.101e-05    9.819e-01
#  Q[ 50, 1]   -2.120e-01    0.000e+00    6.512e-01   -1.328e-04    4.390e-01
#  Q[ 50, 2]   -2.254e-01    0.000e+00    1.104e+00   -8.685e-05    8.780e-01
#  Q[ 50, 3]   -2.006e-01    0.000e+00    7.534e-01   -1.647e-04    5.526e-01
#  Q[ 56, 0]   -3.624e-02    0.000e+00    1.210e+00   -8.101e-05    1.173e+00
#  Q[ 56, 1]   -3.377e-02    0.000e+00    6.512e-01   -1.328e-04    6.173e-01
#  Q[ 56, 2]   -3.590e-02    0.000e+00    1.104e+00   -8.685e-05    1.068e+00
#  Q[ 56, 3]   -3.195e-02    0.000e+00    7.534e-01   -1.647e-04    7.213e-01
#  Q[111, 0]   -1.835e-01    0.000e+00    1.210e+00   -8.101e-05    1.026e+00
#  Q[111, 1]   -1.710e-01    0.000e+00    6.512e-01   -1.328e-04    4.801e-01
#  Q[111, 2]   -1.818e-01    0.000e+00    1.104e+00   -8.685e-05    9.216e-01
#  Q[111, 3]   -1.618e-01    0.000e+00    7.534e-01   -1.647e-04    5.914e-01
#  Q[114, 0]   -1.654e-01    0.000e+00    1.210e+00   -8.101e-05    1.044e+00
#  Q[114, 1]   -1.541e-01    0.000e+00    6.512e-01   -1.328e-04    4.970e-01
#  Q[114, 2]   -1.638e-01    0.000e+00    1.104e+00   -8.685e-05    9.396e-01
#  Q[114, 3]   -1.458e-01    0.000e+00    7.534e-01   -1.647e-04    6.074e-01
#
# --- Norms ---
# ||grad_task_Q||   = 10.035651
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 50.110195
# ||grad_col_lo_Q|| = 0.005267
# ||grad_total_Q||  = 42.116249
#
# === After outer iteration 1 ===
# c0 = 107.4014, H(Q) = 107.1559, loss = 9.9911e+00
# gap = 1.4779e-01, colsum_err = 4.7919e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 6.0000/6.0000/6.0000
#
# Selected gradients for outer iteration 1:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -7.179e-01    0.000e+00    2.168e+00   -7.409e-04    1.450e+00
#  Q[ 50, 1]   -6.903e-01    0.000e+00    1.956e+00   -8.573e-04    1.264e+00
#  Q[ 50, 2]   -7.129e-01    0.000e+00    2.216e+00   -7.440e-04    1.502e+00
#  Q[ 50, 3]   -6.590e-01    0.000e+00    1.806e+00   -8.962e-04    1.146e+00
#  Q[ 56, 0]    1.897e+00    0.000e+00    2.168e+00   -7.409e-04    4.065e+00
#  Q[114, 2]    1.906e+00    1.180e-02    2.650e+00   -1.453e-03    4.566e+00
#  Q[114, 3]    1.812e+00    1.133e-02    2.465e+00   -1.619e-03    4.287e+00
#
# --- Norms ---
# ||grad_task_Q||   = 151.933594
# ||grad_ent_Q||    = 2.805145
# ||grad_col_up_Q|| = 137.254227
# ||grad_col_lo_Q|| = 0.072436
# ||grad_total_Q||  = 246.262619
#
# === After outer iteration 3 ===
# c0 = 101.0540, H(Q) = 101.0556, loss = 8.2165e+00
# gap = 2.6987e-01, colsum_err = 6.9330e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 3:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -1.536e+00    2.390e-02    3.505e+00   -2.032e-03    1.990e+00
#  Q[ 50, 1]   -1.522e+00    2.390e-02    3.173e+00   -2.116e-03    1.674e+00
#  Q[ 50, 2]   -1.484e+00    2.390e-02    3.283e+00   -1.977e-03    1.820e+00
#  Q[ 50, 3]   -1.440e+00    2.390e-02    2.755e+00   -2.167e-03    1.336e+00
#  Q[ 56, 0]    4.767e+00    2.390e-02    3.505e+00   -2.032e-03    8.294e+00
#  Q[ 56, 1]    4.722e+00    2.390e-02    3.173e+00   -2.116e-03    7.917e+00
#  Q[ 56, 2]    4.606e+00    2.390e-02    3.283e+00   -1.977e-03    7.910e+00
#  Q[ 56, 3]    4.469e+00    2.390e-02    2.755e+00   -2.167e-03    7.246e+00
#  Q[111, 0]    1.611e+00    2.921e-03    3.505e+00   -2.032e-03    5.117e+00
#  Q[111, 1]    1.596e+00    3.232e-03    3.173e+00   -2.116e-03    4.770e+00
#  Q[111, 2]    1.556e+00    3.436e-03    3.283e+00   -1.977e-03    4.840e+00
#  Q[111, 3]    1.510e+00    3.665e-03    2.755e+00   -2.167e-03    4.267e+00
#  Q[114, 0]    1.777e+00    4.317e-03    3.505e+00   -2.032e-03    5.284e+00
#  Q[114, 1]    1.760e+00    3.975e-03    3.173e+00   -2.116e-03    4.935e+00
#  Q[114, 2]    1.716e+00    3.898e-03    3.283e+00   -1.977e-03    5.001e+00
#  Q[114, 3]    1.665e+00    3.684e-03    2.755e+00   -2.167e-03    4.422e+00
#
# --- Norms ---
# ||grad_task_Q||   = 146.301514
# ||grad_ent_Q||    = 1.040518
# ||grad_col_up_Q|| = 166.920120
# ||grad_col_lo_Q|| = 0.099599
# ||grad_total_Q||  = 271.172241
#
# === After outer iteration 4 ===
# c0 = 98.0223, H(Q) = 98.0251, loss = 7.2760e+00
# gap = 3.3456e-01, colsum_err = 7.9700e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 4:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
# ||grad_col_lo_Q|| = 0.150030
# ||grad_total_Q||  = 234.400177
#
# === After outer iteration 7 ===
# c0 = 89.4623, H(Q) = 86.7225, loss = 1.2576e+00
# gap = 4.1230e-01, colsum_err = 6.2426e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 7:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -3.041e-01    0.000e+00    3.181e+00   -3.723e-03    2.873e+00
#  Q[ 50, 1]   -3.021e-01    0.000e+00    2.962e+00   -3.502e-03    2.657e+00
#  Q[ 50, 2]   -2.858e-01    0.000e+00    2.941e+00   -3.313e-03    2.651e+00
#  Q[ 50, 3]   -2.811e-01    0.000e+00    2.472e+00   -3.696e-03    2.187e+00
#  Q[ 56, 0]    6.489e-01    0.000e+00    3.181e+00   -3.723e-03    3.826e+00
#  Q[ 56, 1]    6.448e-01    0.000e+00    2.962e+00   -3.502e-03    3.603e+00
#  Q[ 56, 2]    6.100e-01    0.000e+00    2.941e+00   -3.313e-03    3.547e+00
#  Q[ 56, 3]    6.000e-01    0.000e+00    2.472e+00   -3.696e-03    3.068e+00
#  Q[111, 0]    3.070e-01    0.000e+00    3.181e+00   -3.723e-03    3.484e+00
#  Q[111, 1]    3.050e-01    0.000e+00    2.962e+00   -3.502e-03    3.264e+00
#  Q[111, 2]    2.886e-01    0.000e+00    2.941e+00   -3.313e-03    3.226e+00
#  Q[111, 3]    2.838e-01    0.000e+00    2.472e+00   -3.696e-03    2.752e+00
#  Q[114, 0]    3.306e-01    0.000e+00    3.181e+00   -3.723e-03    3.508e+00
#  Q[114, 1]    3.285e-01    0.000e+00    2.962e+00   -3.502e-03    3.287e+00
#  Q[114, 2]    3.107e-01    0.000e+00    2.941e+00   -3.313e-03    3.248e+00
#  Q[114, 3]    3.056e-01    0.000e+00    2.472e+00   -3.696e-03    2.774e+00
#
# --- Norms ---
# ||grad_task_Q||   = 51.510063
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 152.543045
# ||grad_col_lo_Q|| = 0.171724
# ||grad_total_Q||  = 174.335968
#
# === After outer iteration 8 ===
# c0 = 86.7785, H(Q) = 85.0591, loss = 9.8695e-01
# gap = 3.9962e-01, colsum_err = 5.5507e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 8:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -1.857e-01    0.000e+00    2.851e+00   -3.638e-03    2.662e+00
#  Q[ 50, 1]   -1.873e-01    0.000e+00    2.729e+00   -3.388e-03    2.539e+00
#  Q[ 50, 2]   -1.744e-01    0.000e+00    2.652e+00   -3.199e-03    2.475e+00
#  Q[114, 0]    2.295e-01    1.064e-02    2.787e+00   -3.772e-03    3.024e+00
#  Q[114, 1]    2.330e-01    7.614e-03    2.751e+00   -3.478e-03    2.988e+00
#  Q[114, 2]    2.159e-01    7.597e-03    2.666e+00   -3.288e-03    2.886e+00
#  Q[114, 3]    2.158e-01    6.112e-03    2.399e+00   -3.711e-03    2.617e+00
#
# --- Norms ---
# ||grad_task_Q||   = 19.950682
# ||grad_ent_Q||    = 1.863200
# ||grad_col_up_Q|| = 137.095230
# ||grad_col_lo_Q|| = 0.171810
# ||grad_total_Q||  = 143.263977
#
# === After outer iteration 10 ===
# c0 = 81.6499, H(Q) = 81.6345, loss = 1.3022e+00
# gap = 4.2645e-01, colsum_err = 5.0118e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 10:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -1.785e-01    0.000e+00    2.321e+00   -4.293e-03    2.139e+00
#  Q[ 50, 1]   -1.799e-01    0.000e+00    2.352e+00   -3.884e-03    2.168e+00
#  Q[ 50, 2]   -1.692e-01    0.000e+00    2.256e+00   -3.688e-03    2.083e+00
#  Q[ 50, 3]   -1.667e-01    0.000e+00    2.129e+00   -4.123e-03    1.959e+00
#  Q[ 56, 0]    3.318e-01    0.000e+00    2.321e+00   -4.293e-03    2.649e+00
#  Q[ 56, 1]    3.343e-01    0.000e+00    2.352e+00   -3.884e-03    2.682e+00
#  Q[ 56, 2]    3.144e-01    0.000e+00    2.256e+00   -3.688e-03    2.567e+00
#  Q[ 56, 3]    3.097e-01    0.000e+00    2.129e+00   -4.123e-03    2.435e+00
#  Q[111, 0]    2.180e-01    0.000e+00    2.321e+00   -4.293e-03    2.535e+00
#  Q[111, 1]    2.197e-01    0.000e+00    2.352e+00   -3.884e-03    2.567e+00
#  Q[111, 2]    2.066e-01    0.000e+00    2.256e+00   -3.688e-03    2.459e+00
#  Q[111, 3]    2.036e-01    0.000e+00    2.129e+00   -4.123e-03    2.329e+00
#  Q[114, 0]    2.268e-01    0.000e+00    2.321e+00   -4.293e-03    2.544e+00
#  Q[114, 1]    2.285e-01    0.000e+00    2.352e+00   -3.884e-03    2.576e+00
#  Q[114, 2]    2.149e-01    0.000e+00    2.256e+00   -3.688e-03    2.467e+00
#  Q[114, 3]    2.117e-01    0.000e+00    2.129e+00   -4.123e-03    2.337e+00
#
# --- Norms ---
# ||grad_task_Q||   = 50.733810
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 121.227760
# ||grad_col_lo_Q|| = 0.193313
# ||grad_total_Q||  = 142.291306
#
# === After outer iteration 11 ===
# c0 = 79.2004, H(Q) = 78.9689, loss = 9.8419e-01
# gap = 4.4341e-01, colsum_err = 5.2435e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 11:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    8.025e-02    0.000e+00    2.477e+00   -4.825e-03    2.552e+00
#  Q[ 50, 1]    8.113e-02    0.000e+00    2.493e+00   -4.299e-03    2.569e+00
#  Q[ 50, 2]    7.709e-02    0.000e+00    2.383e+00   -4.105e-03    2.456e+00
#  Q[ 50, 3]    7.529e-02    0.000e+00    2.391e+00   -4.550e-03    2.462e+00
#  Q[ 56, 0]   -1.347e-01    0.000e+00    2.477e+00   -4.825e-03    2.337e+00
#  Q[ 56, 1]   -1.362e-01    0.000e+00    2.493e+00   -4.299e-03    2.352e+00
#  Q[ 56, 2]   -1.294e-01    0.000e+00    2.383e+00   -4.105e-03    2.249e+00
#  Q[ 56, 3]   -1.264e-01    0.000e+00    2.391e+00   -4.550e-03    2.260e+00
#  Q[111, 0]   -8.216e-02    0.000e+00    2.477e+00   -4.825e-03    2.390e+00
#  Q[111, 1]   -8.307e-02    0.000e+00    2.493e+00   -4.299e-03    2.405e+00
#  Q[111, 2]   -7.893e-02    0.000e+00    2.383e+00   -4.105e-03    2.300e+00
#  Q[111, 3]   -7.709e-02    0.000e+00    2.391e+00   -4.550e-03    2.309e+00
#  Q[114, 0]   -8.698e-02    0.000e+00    2.477e+00   -4.825e-03    2.385e+00
#  Q[114, 1]   -8.794e-02    0.000e+00    2.493e+00   -4.299e-03    2.400e+00
#  Q[114, 2]   -8.356e-02    0.000e+00    2.383e+00   -4.105e-03    2.295e+00
#  Q[114, 3]   -8.162e-02    0.000e+00    2.391e+00   -4.550e-03    2.305e+00
#
# --- Norms ---
# ||grad_task_Q||   = 16.107670
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 129.302078
# ||grad_col_lo_Q|| = 0.215267
# ||grad_total_Q||  = 124.057442
#
# === After outer iteration 12 ===
# c0 = 76.8244, H(Q) = 76.8247, loss = 9.4166e-01
# gap = 4.5795e-01, colsum_err = 5.1095e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 12:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -2.385e-02    5.156e-03    2.530e+00   -5.246e-03    2.506e+00
#  Q[ 50, 1]   -2.380e-02    5.156e-03    2.331e+00   -4.651e-03    2.308e+00
#  Q[ 50, 2]   -2.317e-02    5.156e-03    2.314e+00   -4.461e-03    2.291e+00
#  Q[ 50, 3]   -2.222e-02    5.156e-03    2.470e+00   -4.892e-03    2.448e+00
#  Q[ 56, 0]    3.834e-02    5.156e-03    2.530e+00   -5.246e-03    2.569e+00
#  Q[ 56, 1]    3.827e-02    4.529e-03    2.331e+00   -4.651e-03    2.369e+00
#  Q[114, 3]    7.349e-02    5.398e-04    2.571e+00   -5.259e-03    2.640e+00
#
# --- Norms ---
# ||grad_task_Q||   = 15.932288
# ||grad_ent_Q||    = 0.169927
# ||grad_col_up_Q|| = 126.361351
# ||grad_col_lo_Q|| = 0.253809
# ||grad_total_Q||  = 129.234268
#
# === After outer iteration 14 ===
# c0 = 72.2840, H(Q) = 72.2843, loss = 1.0128e+00
# gap = 4.9683e-01, colsum_err = 5.4179e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 14:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    4.425e-02    4.336e-03    2.562e+00   -6.203e-03    2.604e+00
#  Q[ 50, 1]    4.346e-02    4.336e-03    2.128e+00   -5.446e-03    2.170e+00
#  Q[ 50, 2]    4.405e-02    4.336e-03    2.427e+00   -5.246e-03    2.470e+00
#  Q[ 50, 3]    4.169e-02    4.336e-03    2.608e+00   -5.616e-03    2.649e+00
#  Q[ 56, 0]   -6.289e-02    4.336e-03    2.562e+00   -6.203e-03    2.497e+00
#  Q[ 56, 1]   -6.178e-02    4.336e-03    2.128e+00   -5.446e-03    2.065e+00
#  Q[ 56, 2]   -6.261e-02    2.435e-03    2.427e+00   -5.246e-03    2.362e+00
#  Q[ 56, 3]   -5.926e-02    4.336e-03    2.608e+00   -5.616e-03    2.548e+00
#  Q[111, 0]   -5.107e-02    3.969e-04    2.562e+00   -6.203e-03    2.505e+00
#  Q[111, 1]   -5.017e-02    4.809e-04    2.128e+00   -5.446e-03    2.072e+00
#  Q[111, 2]   -5.084e-02    6.390e-04    2.427e+00   -5.246e-03    2.372e+00
#  Q[111, 3]   -4.812e-02    6.429e-04    2.608e+00   -5.616e-03    2.555e+00
#  Q[114, 0]   -5.242e-02    4.336e-03    2.562e+00   -6.203e-03    2.507e+00
#  Q[114, 1]   -5.149e-02    1.858e-03    2.128e+00   -5.446e-03    2.072e+00
#  Q[114, 2]   -5.218e-02    2.398e-03    2.427e+00   -5.246e-03    2.372e+00
#  Q[114, 3]   -4.939e-02    6.242e-04    2.608e+00   -5.616e-03    2.554e+00
#
# --- Norms ---
# ||grad_task_Q||   = 27.968258
# ||grad_ent_Q||    = 0.198246
# ||grad_col_up_Q|| = 127.227470
# ||grad_col_lo_Q|| = 0.273644
# ||grad_total_Q||  = 123.297173
#
# === After outer iteration 15 ===
# c0 = 70.1155, H(Q) = 70.0445, loss = 1.0558e+00
# gap = 4.9378e-01, colsum_err = 5.5118e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 15:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.066e-01    0.000e+00    2.465e+00   -6.645e-03    2.565e+00
#  Q[ 50, 1]    1.029e-01    0.000e+00    2.131e+00   -5.840e-03    2.228e+00
#  Q[ 50, 2]    1.077e-01    0.000e+00    2.574e+00   -5.612e-03    2.676e+00
#  Q[ 50, 3]    1.005e-01    0.000e+00    2.459e+00   -5.965e-03    2.554e+00
#  Q[ 56, 0]   -1.419e-01    0.000e+00    2.465e+00   -6.645e-03    2.316e+00
#  Q[ 56, 1]   -1.371e-01    0.000e+00    2.131e+00   -5.840e-03    1.988e+00
#  Q[ 56, 2]   -1.434e-01    0.000e+00    2.574e+00   -5.612e-03    2.425e+00
#  Q[ 56, 3]   -1.339e-01    0.000e+00    2.459e+00   -5.965e-03    2.320e+00
#  Q[111, 0]   -1.239e-01    0.000e+00    2.465e+00   -6.645e-03    2.334e+00
#  Q[111, 1]   -1.196e-01    0.000e+00    2.131e+00   -5.840e-03    2.005e+00
#  Q[111, 2]   -1.252e-01    0.000e+00    2.574e+00   -5.612e-03    2.443e+00
#  Q[111, 3]   -1.169e-01    0.000e+00    2.459e+00   -5.965e-03    2.337e+00
#  Q[114, 0]   -1.262e-01    0.000e+00    2.465e+00   -6.645e-03    2.332e+00
#  Q[114, 1]   -1.219e-01    0.000e+00    2.131e+00   -5.840e-03    2.003e+00
#  Q[114, 2]   -1.275e-01    0.000e+00    2.574e+00   -5.612e-03    2.441e+00
#  Q[114, 3]   -1.190e-01    0.000e+00    2.459e+00   -5.965e-03    2.334e+00
#
# --- Norms ---
# ||grad_task_Q||   = 39.078400
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 126.889313
# ||grad_col_lo_Q|| = 0.292586
# ||grad_total_Q||  = 123.948448
#
# === After outer iteration 16 ===
# c0 = 68.0121, H(Q) = 67.9697, loss = 9.8568e-01
# gap = 4.8483e-01, colsum_err = 5.6385e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 16:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    2.816e-02    0.000e+00    2.513e+00   -7.078e-03    2.534e+00
#  Q[ 50, 1]    2.693e-02    0.000e+00    2.268e+00   -6.215e-03    2.288e+00
#  Q[ 50, 2]    2.892e-02    0.000e+00    2.750e+00   -5.935e-03    2.773e+00
#  Q[ 50, 3]    2.663e-02    0.000e+00    2.386e+00   -6.303e-03    2.407e+00
#  Q[ 56, 0]   -3.593e-02    0.000e+00    2.513e+00   -7.078e-03    2.470e+00
#  Q[ 56, 1]   -3.435e-02    0.000e+00    2.268e+00   -6.215e-03    2.227e+00
#  Q[ 56, 2]   -3.690e-02    0.000e+00    2.750e+00   -5.935e-03    2.708e+00
#  Q[ 56, 3]   -3.397e-02    0.000e+00    2.386e+00   -6.303e-03    2.346e+00
#  Q[111, 0]   -3.203e-02    0.000e+00    2.513e+00   -7.078e-03    2.474e+00
#  Q[111, 1]   -3.063e-02    0.000e+00    2.268e+00   -6.215e-03    2.231e+00
#  Q[111, 2]   -3.290e-02    0.000e+00    2.750e+00   -5.935e-03    2.712e+00
#  Q[111, 3]   -3.028e-02    0.000e+00    2.386e+00   -6.303e-03    2.350e+00
#  Q[114, 0]   -3.268e-02    0.000e+00    2.513e+00   -7.078e-03    2.473e+00
#  Q[114, 1]   -3.125e-02    0.000e+00    2.268e+00   -6.215e-03    2.230e+00
#  Q[114, 2]   -3.356e-02    0.000e+00    2.750e+00   -5.935e-03    2.711e+00
#  Q[114, 3]   -3.090e-02    0.000e+00    2.386e+00   -6.303e-03    2.349e+00
#
# --- Norms ---
# ||grad_task_Q||   = 19.392160
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 130.786819
# ||grad_col_lo_Q|| = 0.310707
# ||grad_total_Q||  = 127.715919
#
# === After outer iteration 17 ===
# c0 = 65.9717, H(Q) = 65.7368, loss = 9.4331e-01
# gap = 4.9790e-01, colsum_err = 5.5194e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 17:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.252e-02    0.000e+00    2.365e+00   -7.495e-03    2.370e+00
#  Q[ 50, 1]    1.175e-02    0.000e+00    2.334e+00   -6.594e-03    2.339e+00
#  Q[ 50, 2]    1.309e-02    0.000e+00    2.755e+00   -6.257e-03    2.762e+00
#  Q[ 50, 3]    1.171e-02    0.000e+00    2.265e+00   -6.650e-03    2.270e+00
#  Q[ 56, 0]   -1.521e-02    0.000e+00    2.365e+00   -7.495e-03    2.342e+00
#  Q[ 56, 1]   -1.427e-02    0.000e+00    2.334e+00   -6.594e-03    2.313e+00
#  Q[ 56, 2]   -1.590e-02    0.000e+00    2.755e+00   -6.257e-03    2.733e+00
#  Q[ 56, 3]   -1.422e-02    0.000e+00    2.265e+00   -6.650e-03    2.244e+00
#  Q[111, 0]   -1.530e-02    0.000e+00    2.365e+00   -7.495e-03    2.342e+00
#  Q[111, 1]   -1.435e-02    0.000e+00    2.334e+00   -6.594e-03    2.313e+00
#  Q[111, 2]   -1.599e-02    0.000e+00    2.755e+00   -6.257e-03    2.733e+00
#  Q[111, 3]   -1.431e-02    0.000e+00    2.265e+00   -6.650e-03    2.244e+00
#  Q[114, 0]   -1.540e-02    0.000e+00    2.365e+00   -7.495e-03    2.342e+00
#  Q[114, 1]   -1.445e-02    0.000e+00    2.334e+00   -6.594e-03    2.313e+00
#  Q[114, 2]   -1.611e-02    0.000e+00    2.755e+00   -6.257e-03    2.733e+00
#  Q[114, 3]   -1.441e-02    0.000e+00    2.265e+00   -6.650e-03    2.244e+00
#
# --- Norms ---
# ||grad_task_Q||   = 7.468324
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 130.657455
# ||grad_col_lo_Q|| = 0.328486
# ||grad_total_Q||  = 130.677322
#
# === After outer iteration 18 ===
# c0 = 63.9925, H(Q) = 63.9248, loss = 9.7291e-01
# gap = 4.9961e-01, colsum_err = 5.5664e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 18:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]   -7.518e-02    0.000e+00    2.315e+00   -7.871e-03    2.232e+00
#  Q[ 50, 1]   -6.941e-02    0.000e+00    2.650e+00   -6.906e-03    2.574e+00
#  Q[ 50, 2]   -8.016e-02    0.000e+00    2.854e+00   -6.524e-03    2.767e+00
#  Q[ 50, 3]   -6.974e-02    0.000e+00    2.372e+00   -6.951e-03    2.295e+00
#  Q[ 56, 0]    8.764e-02    0.000e+00    2.315e+00   -7.871e-03    2.395e+00
#  Q[ 56, 1]    8.091e-02    0.000e+00    2.650e+00   -6.906e-03    2.724e+00
#  Q[ 56, 2]    9.344e-02    0.000e+00    2.854e+00   -6.524e-03    2.941e+00
#  Q[ 56, 3]    8.129e-02    0.000e+00    2.372e+00   -6.951e-03    2.446e+00
#  Q[111, 0]    8.841e-02    0.000e+00    2.315e+00   -7.871e-03    2.396e+00
#  Q[111, 1]    8.162e-02    0.000e+00    2.650e+00   -6.906e-03    2.725e+00
#  Q[111, 2]    9.426e-02    0.000e+00    2.854e+00   -6.524e-03    2.942e+00
#  Q[111, 3]    8.201e-02    0.000e+00    2.372e+00   -6.951e-03    2.447e+00
#  Q[114, 0]    8.947e-02    0.000e+00    2.315e+00   -7.871e-03    2.397e+00
#  Q[114, 1]    8.260e-02    0.000e+00    2.650e+00   -6.906e-03    2.726e+00
#  Q[114, 2]    9.540e-02    0.000e+00    2.854e+00   -6.524e-03    2.943e+00
#  Q[114, 3]    8.299e-02    0.000e+00    2.372e+00   -6.951e-03    2.448e+00
#
# --- Norms ---
# ||grad_task_Q||   = 25.762413
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 136.672379
# ||grad_col_lo_Q|| = 0.343731
# ||grad_total_Q||  = 142.030563
#
# === After outer iteration 19 ===
# c0 = 62.0728, H(Q) = 61.8126, loss = 9.5711e-01
# gap = 4.9744e-01, colsum_err = 5.8570e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 19:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    9.399e-02    0.000e+00    2.454e+00   -8.270e-03    2.539e+00
#  Q[ 50, 1]    8.556e-02    0.000e+00    2.879e+00   -7.203e-03    2.957e+00
#  Q[ 50, 2]    1.025e-01    0.000e+00    2.740e+00   -6.813e-03    2.836e+00
#  Q[114, 0]   -5.663e-03    0.000e+00    2.584e+00   -8.600e-03    2.570e+00
#  Q[114, 1]   -5.092e-03    0.000e+00    3.097e+00   -7.414e-03    3.085e+00
#  Q[114, 2]   -6.321e-03    0.000e+00    2.714e+00   -7.062e-03    2.701e+00
#  Q[114, 3]   -5.144e-03    0.000e+00    2.422e+00   -7.523e-03    2.409e+00
#
# --- Norms ---
# ||grad_task_Q||   = 25.895920
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 143.373611
# ||grad_col_lo_Q|| = 0.373181
# ||grad_total_Q||  = 148.040863
#
# === After outer iteration 21 ===
# c0 = 58.4043, H(Q) = 58.2972, loss = 9.9742e-01
# gap = 4.6461e-01, colsum_err = 6.8841e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 21:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    2.425e-01    0.000e+00    2.879e+00   -8.959e-03    3.113e+00
#  Q[ 50, 1]    2.159e-01    0.000e+00    3.280e+00   -7.648e-03    3.488e+00
#  Q[ 50, 2]    2.770e-01    0.000e+00    2.532e+00   -7.358e-03    2.802e+00
#  Q[ 50, 3]    2.186e-01    0.000e+00    2.441e+00   -7.810e-03    2.652e+00
#  Q[ 56, 0]   -2.394e-01    0.000e+00    2.879e+00   -8.959e-03    2.631e+00
#  Q[ 56, 1]   -2.132e-01    0.000e+00    3.280e+00   -7.648e-03    3.059e+00
#  Q[ 56, 2]   -2.736e-01    0.000e+00    2.532e+00   -7.358e-03    2.251e+00
#  Q[ 56, 3]   -2.158e-01    0.000e+00    2.441e+00   -7.810e-03    2.218e+00
#  Q[111, 0]   -2.884e-01    0.000e+00    2.879e+00   -8.959e-03    2.582e+00
#  Q[111, 1]   -2.568e-01    0.000e+00    3.280e+00   -7.648e-03    3.016e+00
#  Q[111, 2]   -3.295e-01    0.000e+00    2.532e+00   -7.358e-03    2.195e+00
#  Q[111, 3]   -2.600e-01    0.000e+00    2.441e+00   -7.810e-03    2.173e+00
#  Q[114, 0]   -2.877e-01    0.000e+00    2.879e+00   -8.959e-03    2.582e+00
#  Q[114, 1]   -2.562e-01    0.000e+00    3.280e+00   -7.648e-03    3.016e+00
#  Q[114, 2]   -3.287e-01    0.000e+00    2.532e+00   -7.358e-03    2.196e+00
#  Q[114, 3]   -2.593e-01    0.000e+00    2.441e+00   -7.810e-03    2.174e+00
#
# --- Norms ---
# ||grad_task_Q||   = 22.179514
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 147.503677
# ||grad_col_lo_Q|| = 0.388183
# ||grad_total_Q||  = 145.147278
#
# === After outer iteration 22 ===
# c0 = 56.6521, H(Q) = 56.3458, loss = 1.0629e+00
# gap = 4.8424e-01, colsum_err = 7.3118e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 22:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    3.316e-01    0.000e+00    3.153e+00   -9.262e-03    3.476e+00
#  Q[ 50, 1]    2.921e-01    0.000e+00    3.437e+00   -7.846e-03    3.721e+00
#  Q[ 50, 2]    3.877e-01    0.000e+00    2.486e+00   -7.628e-03    2.866e+00
#  Q[ 50, 3]    2.965e-01    0.000e+00    2.494e+00   -8.055e-03    2.783e+00
#  Q[ 56, 0]   -3.107e-01    0.000e+00    3.153e+00   -9.262e-03    2.833e+00
#  Q[ 56, 1]   -2.738e-01    0.000e+00    3.437e+00   -7.846e-03    3.155e+00
#  Q[ 56, 2]   -3.634e-01    0.000e+00    2.486e+00   -7.628e-03    2.115e+00
#  Q[ 56, 3]   -2.779e-01    0.000e+00    2.494e+00   -8.055e-03    2.208e+00
#  Q[111, 0]   -3.886e-01    0.000e+00    3.153e+00   -9.262e-03    2.755e+00
#  Q[111, 1]   -3.424e-01    0.000e+00    3.437e+00   -7.846e-03    3.087e+00
#  Q[111, 2]   -4.545e-01    0.000e+00    2.486e+00   -7.628e-03    2.024e+00
#  Q[111, 3]   -3.475e-01    0.000e+00    2.494e+00   -8.055e-03    2.139e+00
#  Q[114, 0]   -3.886e-01    0.000e+00    3.153e+00   -9.262e-03    2.755e+00
#  Q[114, 1]   -3.424e-01    0.000e+00    3.437e+00   -7.846e-03    3.087e+00
#  Q[114, 2]   -4.544e-01    0.000e+00    2.486e+00   -7.628e-03    2.024e+00
#  Q[114, 3]   -3.475e-01    0.000e+00    2.494e+00   -8.055e-03    2.139e+00
#
# --- Norms ---
# ||grad_task_Q||   = 43.540627
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 153.607391
# ||grad_col_lo_Q|| = 0.401255
# ||grad_total_Q||  = 153.381653
#
# === After outer iteration 23 ===
# c0 = 54.9526, H(Q) = 54.5499, loss = 1.1440e+00
# gap = 4.9630e-01, colsum_err = 7.6089e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 23:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    4.361e-01    0.000e+00    3.337e+00   -9.507e-03    3.764e+00
#  Q[ 50, 1]    3.806e-01    0.000e+00    3.530e+00   -7.997e-03    3.903e+00
#  Q[ 50, 2]    5.206e-01    0.000e+00    2.580e+00   -7.841e-03    3.092e+00
#  Q[ 50, 3]    3.880e-01    0.000e+00    2.471e+00   -8.243e-03    2.851e+00
#  Q[ 56, 0]   -3.905e-01    0.000e+00    3.337e+00   -9.507e-03    2.937e+00
#  Q[ 56, 1]   -3.408e-01    0.000e+00    3.530e+00   -7.997e-03    3.182e+00
#  Q[ 56, 2]   -4.662e-01    0.000e+00    2.580e+00   -7.841e-03    2.106e+00
#  Q[ 56, 3]   -3.474e-01    0.000e+00    2.471e+00   -8.243e-03    2.115e+00
#  Q[111, 0]   -5.100e-01    0.000e+00    3.337e+00   -9.507e-03    2.818e+00
#  Q[111, 1]   -4.451e-01    0.000e+00    3.530e+00   -7.997e-03    3.077e+00
#  Q[111, 2]   -6.088e-01    0.000e+00    2.580e+00   -7.841e-03    1.963e+00
#  Q[111, 3]   -4.537e-01    0.000e+00    2.471e+00   -8.243e-03    2.009e+00
#  Q[114, 0]   -5.085e-01    0.000e+00    3.337e+00   -9.507e-03    2.819e+00
#  Q[114, 1]   -4.438e-01    0.000e+00    3.530e+00   -7.997e-03    3.079e+00
#  Q[114, 2]   -6.071e-01    0.000e+00    2.580e+00   -7.841e-03    1.965e+00
#  Q[114, 3]   -4.524e-01    0.000e+00    2.471e+00   -8.243e-03    2.011e+00
#
# --- Norms ---
# ||grad_task_Q||   = 57.247959
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 157.873413
# ||grad_col_lo_Q|| = 0.411399
# ||grad_total_Q||  = 160.800262
#
# === After outer iteration 24 ===
# c0 = 53.3040, H(Q) = 52.6882, loss = 1.2710e+00
# gap = 4.9710e-01, colsum_err = 7.8004e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 24:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    5.619e-01    0.000e+00    3.452e+00   -9.721e-03    4.004e+00
#  Q[ 50, 1]    4.876e-01    0.000e+00    3.578e+00   -8.121e-03    4.057e+00
#  Q[ 50, 2]    6.838e-01    0.000e+00    2.774e+00   -8.010e-03    3.450e+00
#  Q[ 50, 3]    5.015e-01    0.000e+00    2.541e+00   -8.400e-03    3.034e+00
#  Q[ 56, 0]   -4.836e-01    0.000e+00    3.452e+00   -9.721e-03    2.958e+00
#  Q[ 56, 1]   -4.197e-01    0.000e+00    3.578e+00   -8.121e-03    3.150e+00
#  Q[ 56, 2]   -5.885e-01    0.000e+00    2.774e+00   -8.010e-03    2.177e+00
#  Q[ 56, 3]   -4.316e-01    0.000e+00    2.541e+00   -8.400e-03    2.101e+00
#  Q[111, 0]   -6.507e-01    0.000e+00    3.452e+00   -9.721e-03    2.791e+00
#  Q[111, 1]   -5.647e-01    0.000e+00    3.578e+00   -8.121e-03    3.005e+00
#  Q[111, 2]   -7.920e-01    0.000e+00    2.774e+00   -8.010e-03    1.974e+00
#  Q[111, 3]   -5.808e-01    0.000e+00    2.541e+00   -8.400e-03    1.952e+00
#  Q[114, 0]   -6.490e-01    0.000e+00    3.452e+00   -9.721e-03    2.793e+00
#  Q[114, 1]   -5.633e-01    0.000e+00    3.578e+00   -8.121e-03    3.007e+00
#  Q[114, 2]   -7.899e-01    0.000e+00    2.774e+00   -8.010e-03    1.976e+00
#  Q[114, 3]   -5.793e-01    0.000e+00    2.541e+00   -8.400e-03    1.954e+00
#
# --- Norms ---
# ||grad_task_Q||   = 72.105072
# ||grad_ent_Q||    = 0.000000
# ||grad_col_up_Q|| = 161.104370
# ||grad_col_lo_Q|| = 0.420003
# ||grad_total_Q||  = 168.681931
#
# === After outer iteration 25 ===
# c0 = 51.7049, H(Q) = 51.2145, loss = 1.2800e+00
# gap = 4.8484e-01, colsum_err = 7.8950e-01
# Penalties: cE = 1.0000, cU[max/min/mean] = 6.0000/6.0000/6.0000, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 25:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    5.909e-01    0.000e+00    3.669e+00   -9.876e-03    4.250e+00
#  Q[ 50, 1]    5.094e-01    0.000e+00    3.584e+00   -8.201e-03    4.085e+00
#  Q[ 50, 2]    7.321e-01    0.000e+00    2.941e+00   -8.126e-03    3.665e+00
#  Q[ 50, 3]    5.282e-01    0.000e+00    2.712e+00   -8.506e-03    3.231e+00
#  Q[ 56, 0]   -4.918e-01    0.000e+00    3.669e+00   -9.876e-03    3.168e+00
#  Q[ 56, 1]   -4.240e-01    0.000e+00    3.584e+00   -8.201e-03    3.152e+00
#  Q[ 56, 2]   -6.093e-01    0.000e+00    2.941e+00   -8.126e-03    2.324e+00
#  Q[ 56, 3]   -4.396e-01    0.000e+00    2.712e+00   -8.506e-03    2.264e+00
#  Q[111, 0]   -6.744e-01    0.000e+00    3.669e+00   -9.876e-03    2.985e+00
#  Q[111, 1]   -5.814e-01    0.000e+00    3.584e+00   -8.201e-03    2.994e+00
#  Q[111, 2]   -8.356e-01    0.000e+00    2.941e+00   -8.126e-03    2.098e+00
#  Q[111, 3]   -6.028e-01    0.000e+00    2.712e+00   -8.506e-03    2.100e+00
#  Q[114, 0]   -6.716e-01    0.000e+00    3.669e+00   -9.876e-03    2.988e+00
# ...
# ||grad_ent_Q||    = 5.180265
# ||grad_col_up_Q|| = 453.672943
# ||grad_col_lo_Q|| = 0.711520
# ||grad_total_Q||  = 455.862091
#
# === After outer iteration 97 ===
# c0 = 5.7689, H(Q) = 5.7613, loss = 1.3079e+00
# gap = 4.4690e-01, colsum_err = 1.1740e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 30.9587/6.0000/8.5086, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 97:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    9.762e-02    1.193e-01    3.093e+01   -3.696e-02    3.111e+01
#  Q[ 50, 1]    1.553e-01    1.193e-01    5.997e+00   -7.797e-03    6.264e+00
#  Q[ 50, 2]    2.876e-01    1.193e-01    6.663e+00   -5.785e-03    7.064e+00
#  Q[114, 0]   -1.750e-01    1.307e-01    3.712e+01   -3.844e-02    3.703e+01
#  Q[114, 1]   -2.734e-01    1.307e-01    5.997e+00   -7.712e-03    5.847e+00
#  Q[114, 2]   -5.070e-01    1.307e-01    6.657e+00   -5.697e-03    6.274e+00
#  Q[114, 3]   -2.614e-01    1.307e-01    6.356e+00   -4.384e-03    6.221e+00
#
# --- Norms ---
# ||grad_task_Q||   = 48.857178
# ||grad_ent_Q||    = 6.342350
# ||grad_col_up_Q|| = 518.303589
# ||grad_col_lo_Q|| = 0.738589
# ||grad_total_Q||  = 520.793274
#
# === After outer iteration 99 ===
# c0 = 5.4280, H(Q) = 5.4188, loss = 1.3122e+00
# gap = 4.5187e-01, colsum_err = 1.1741e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 37.1504/6.0000/8.8782, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 99:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.046e-01    1.433e-01    3.712e+01   -4.019e-02    3.733e+01
#  Q[ 50, 1]    1.606e-01    1.433e-01    5.997e+00   -7.627e-03    6.293e+00
#  Q[ 50, 2]    2.984e-01    1.433e-01    6.648e+00   -5.608e-03    7.084e+00
#  Q[ 50, 3]    1.536e-01    1.433e-01    6.293e+00   -4.298e-03    6.585e+00
#  Q[ 56, 0]   -1.025e-01    1.433e-01    3.712e+01   -4.019e-02    3.712e+01
#  Q[ 56, 1]   -1.574e-01    1.433e-01    5.997e+00   -7.627e-03    5.975e+00
#  Q[ 56, 2]   -2.924e-01    1.433e-01    6.648e+00   -5.608e-03    6.494e+00
#  Q[ 56, 3]   -1.505e-01    1.433e-01    6.293e+00   -4.298e-03    6.281e+00
#  Q[111, 0]   -2.028e-01   -1.431e-01    3.712e+01   -4.019e-02    3.673e+01
#  Q[111, 1]   -3.113e-01    1.433e-01    5.997e+00   -7.627e-03    5.821e+00
#  Q[111, 2]   -5.784e-01    1.433e-01    6.648e+00   -5.608e-03    6.208e+00
#  Q[111, 3]   -2.976e-01    1.433e-01    6.293e+00   -4.298e-03    6.134e+00
#  Q[114, 0]   -1.859e-01    1.433e-01    3.712e+01   -4.019e-02    3.703e+01
#  Q[114, 1]   -2.854e-01    1.433e-01    5.997e+00   -7.627e-03    5.847e+00
#  Q[114, 2]   -5.303e-01    1.433e-01    6.648e+00   -5.608e-03    6.256e+00
#  Q[114, 3]   -2.729e-01    1.433e-01    6.293e+00   -4.298e-03    6.159e+00
#
# --- Norms ---
# ||grad_task_Q||   = 50.745907
# ||grad_ent_Q||    = 6.975920
# ||grad_col_up_Q|| = 518.254211
# ||grad_col_lo_Q|| = 0.754656
# ||grad_total_Q||  = 521.183350
#
# === After outer iteration 100 ===
# c0 = 5.2652, H(Q) = 5.2551, loss = 1.3250e+00
# gap = 4.5388e-01, colsum_err = 1.1743e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 37.1504/6.0000/8.8782, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 100:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.116e-01    1.583e-01    3.712e+01   -4.193e-02    3.735e+01
#  Q[ 50, 1]    1.684e-01    1.583e-01    5.997e+00   -7.542e-03    6.316e+00
#  Q[ 50, 2]    3.131e-01    1.583e-01    6.641e+00   -5.520e-03    7.106e+00
#  Q[ 50, 3]    1.611e-01    1.583e-01    6.230e+00   -4.215e-03    6.545e+00
#  Q[ 56, 0]   -1.095e-01    1.583e-01    3.712e+01   -4.193e-02    3.712e+01
#  Q[ 56, 1]   -1.653e-01    1.583e-01    5.997e+00   -7.542e-03    5.983e+00
#  Q[ 56, 2]   -3.073e-01    1.583e-01    6.641e+00   -5.520e-03    6.486e+00
#  Q[ 56, 3]   -1.581e-01    1.583e-01    6.230e+00   -4.215e-03    6.226e+00
#  Q[111, 0]   -2.117e-01   -1.581e-01    3.712e+01   -4.193e-02    3.671e+01
#  Q[111, 1]   -3.195e-01    1.583e-01    5.997e+00   -7.542e-03    5.828e+00
#  Q[111, 2]   -5.939e-01    1.583e-01    6.641e+00   -5.520e-03    6.199e+00
#  Q[111, 3]   -3.056e-01    1.583e-01    6.230e+00   -4.215e-03    6.078e+00
#  Q[114, 0]   -1.938e-01    1.583e-01    3.712e+01   -4.193e-02    3.704e+01
#  Q[114, 1]   -2.925e-01    1.583e-01    5.997e+00   -7.542e-03    5.855e+00
#  Q[114, 2]   -5.437e-01    1.583e-01    6.641e+00   -5.520e-03    6.250e+00
#  Q[114, 3]   -2.798e-01    1.583e-01    6.230e+00   -4.215e-03    6.104e+00
#
# --- Norms ---
# ||grad_task_Q||   = 51.965870
# ||grad_ent_Q||    = 7.711971
# ||grad_col_up_Q|| = 518.260437
# ||grad_col_lo_Q|| = 0.771098
# ||grad_total_Q||  = 521.656067
#
# === After outer iteration 101 ===
# c0 = 5.1072, H(Q) = 5.0960, loss = 1.2930e+00
# gap = 4.5566e-01, colsum_err = 1.1748e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 37.1504/6.0000/9.1611, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 101:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.130e-01    1.732e-01    3.712e+01   -4.367e-02    3.736e+01
#  Q[ 50, 1]    1.678e-01    1.732e-01    5.997e+00   -7.456e-03    6.331e+00
#  Q[ 50, 2]    3.122e-01    1.732e-01    6.633e+00   -5.432e-03    7.113e+00
#  Q[ 50, 3]    1.605e-01    1.732e-01    6.164e+00   -4.135e-03    6.494e+00
#  Q[ 56, 0]   -1.113e-01    1.732e-01    3.712e+01   -4.367e-02    3.714e+01
#  Q[ 56, 1]   -1.652e-01    1.732e-01    5.997e+00   -7.456e-03    5.998e+00
#  Q[ 56, 2]   -3.073e-01    1.732e-01    6.633e+00   -5.432e-03    6.494e+00
#  Q[ 56, 3]   -1.580e-01    1.732e-01    6.164e+00   -4.135e-03    6.175e+00
#  Q[111, 0]   -2.089e-01   -1.731e-01    3.712e+01   -4.367e-02    3.669e+01
#  Q[111, 1]   -3.101e-01    1.732e-01    5.997e+00   -7.456e-03    5.853e+00
#  Q[111, 2]   -5.769e-01    1.732e-01    6.633e+00   -5.432e-03    6.224e+00
#  Q[111, 3]   -2.967e-01    1.732e-01    6.164e+00   -4.135e-03    6.037e+00
#  Q[114, 0]   -1.910e-01    1.732e-01    3.712e+01   -4.367e-02    3.706e+01
#  Q[114, 1]   -2.835e-01    1.732e-01    5.997e+00   -7.456e-03    5.880e+00
#  Q[114, 2]   -5.275e-01    1.732e-01    6.633e+00   -5.432e-03    6.274e+00
#  Q[114, 3]   -2.713e-01    1.732e-01    6.164e+00   -4.135e-03    6.062e+00
#
# --- Norms ---
# ||grad_task_Q||   = 49.903244
# ||grad_ent_Q||    = 8.443590
# ||grad_col_up_Q|| = 534.444641
# ||grad_col_lo_Q|| = 0.788044
# ||grad_total_Q||  = 538.109558
#
# === After outer iteration 102 ===
# c0 = 4.9540, H(Q) = 4.9415, loss = 1.3149e+00
# gap = 4.5769e-01, colsum_err = 1.1751e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 44.5805/6.0000/9.6046, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 102:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.192e-01    1.864e-01    4.454e+01   -4.541e-02    4.480e+01
#  Q[ 50, 1]    1.743e-01    1.864e-01    5.997e+00   -7.371e-03    6.351e+00
#  Q[ 50, 2]    3.247e-01    1.864e-01    6.626e+00   -5.345e-03    7.131e+00
#  Q[ 50, 3]    1.667e-01    1.864e-01    6.093e+00   -4.057e-03    6.442e+00
#  Q[ 56, 0]   -1.177e-01    1.864e-01    4.454e+01   -4.541e-02    4.456e+01
#  Q[ 56, 1]   -1.721e-01    1.864e-01    5.997e+00   -7.371e-03    6.004e+00
#  Q[ 56, 2]   -3.206e-01    1.864e-01    6.626e+00   -5.345e-03    6.486e+00
#  Q[ 56, 3]   -1.646e-01    1.864e-01    6.093e+00   -4.057e-03    6.111e+00
#  Q[111, 0]   -2.179e-01   -1.862e-01    4.454e+01   -4.541e-02    4.409e+01
#  Q[111, 1]   -3.186e-01    1.864e-01    5.997e+00   -7.371e-03    5.858e+00
#  Q[111, 2]   -5.934e-01    1.864e-01    6.626e+00   -5.345e-03    6.213e+00
#  Q[111, 3]   -3.047e-01    1.864e-01    6.093e+00   -4.057e-03    5.971e+00
#  Q[114, 0]   -1.990e-01    1.864e-01    4.454e+01   -4.541e-02    4.448e+01
#  Q[114, 1]   -2.909e-01    1.864e-01    5.997e+00   -7.371e-03    5.885e+00
#  Q[114, 2]   -5.420e-01    1.864e-01    6.626e+00   -5.345e-03    6.265e+00
#  Q[114, 3]   -2.783e-01    1.864e-01    6.093e+00   -4.057e-03    5.997e+00
#
# --- Norms ---
# ||grad_task_Q||   = 51.893719
# ||grad_ent_Q||    = 9.073813
# ||grad_col_up_Q|| = 598.534912
# ||grad_col_lo_Q|| = 0.805784
# ||grad_total_Q||  = 602.258118
#
# === After outer iteration 103 ===
# c0 = 4.8054, H(Q) = 4.7925, loss = 1.3073e+00
# gap = 4.5912e-01, colsum_err = 1.1756e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 44.5805/6.0000/9.6046, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 103:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.228e-01    2.031e-01    4.454e+01   -4.745e-02    4.482e+01
#  Q[ 50, 1]    1.770e-01    2.031e-01    5.997e+00   -7.285e-03    6.370e+00
#  Q[ 50, 2]    3.295e-01    2.031e-01    6.617e+00   -5.257e-03    7.144e+00
#  Q[ 50, 3]    1.692e-01    2.031e-01    6.020e+00   -3.980e-03    6.389e+00
#  Q[ 56, 0]   -1.211e-01    2.031e-01    4.454e+01   -4.745e-02    4.458e+01
#  Q[ 56, 1]   -1.745e-01    2.031e-01    5.997e+00   -7.285e-03    6.019e+00
#  Q[ 56, 2]   -3.249e-01    2.031e-01    6.617e+00   -5.257e-03    6.490e+00
#  Q[ 56, 3]   -1.668e-01    2.031e-01    6.020e+00   -3.980e-03    6.053e+00
#  Q[111, 0]   -2.242e-01   -2.029e-01    4.454e+01   -4.745e-02    4.407e+01
#  Q[111, 1]   -3.232e-01    2.031e-01    5.997e+00   -7.285e-03    5.870e+00
#  Q[111, 2]   -6.017e-01    2.031e-01    6.617e+00   -5.257e-03    6.213e+00
#  Q[111, 3]   -3.089e-01    2.031e-01    6.020e+00   -3.980e-03    5.911e+00
#  Q[114, 0]   -2.045e-01    2.031e-01    4.454e+01   -4.745e-02    4.449e+01
#  Q[114, 1]   -2.949e-01    2.031e-01    5.997e+00   -7.285e-03    5.898e+00
#  Q[114, 2]   -5.490e-01    2.031e-01    6.617e+00   -5.257e-03    6.266e+00
#  Q[114, 3]   -2.819e-01    2.031e-01    6.020e+00   -3.980e-03    5.938e+00
#
# --- Norms ---
# ||grad_task_Q||   = 51.589520
# ||grad_ent_Q||    = 9.910855
# ||grad_col_up_Q|| = 598.244507
# ||grad_col_lo_Q|| = 0.826184
# ||grad_total_Q||  = 602.413818
#
# === After outer iteration 104 ===
# c0 = 4.6612, H(Q) = 4.6552, loss = 1.3860e+00
# gap = 4.5937e-01, colsum_err = 1.1754e+00
# Penalties: cE = 1.0000, cU[max/min/mean] = 44.5805/6.0000/9.7539, cL[max/min/mean] = 7.2000/6.0000/6.7800
#
# Selected gradients for outer iteration 104:
#
# --- Final gradient contributions on Q[i,j] ---
#  entry        task          entropy       col_up        col_lo        total
# ----------------------------------------------------------------------------
#  Q[ 50, 0]    1.359e-01    2.253e-01    4.454e+01   -4.947e-02    4.485e+01
#  Q[ 50, 1]    1.934e-01    2.253e-01    5.998e+00   -7.200e-03    6.409e+00
#  Q[ 50, 2]    3.595e-01    2.253e-01    6.599e+00   -5.169e-03    7.178e+00
#  Q[ 50, 3]    1.848e-01    2.253e-01    5.943e+00   -3.907e-03    6.349e+00
#  Q[ 56, 0]   -1.341e-01    2.253e-01    4.454e+01   -4.947e-02    4.458e+01
#  Q[ 56, 1]   -1.909e-01    2.253e-01    5.998e+00   -7.200e-03    6.025e+00
#  Q[ 56, 2]   -3.548e-01    2.253e-01    6.599e+00   -5.169e-03    6.464e+00
#  Q[ 56, 3]   -1.824e-01    2.253e-01    5.943e+00   -3.907e-03    5.982e+00
#  Q[111, 0]   -2.474e-01   -2.251e-01    4.454e+01   -4.947e-02    4.402e+01
#  Q[111, 1]   -3.523e-01    2.253e-01    5.998e+00   -7.200e-03    5.863e+00
#  Q[111, 2]   -6.547e-01    2.253e-01    6.599e+00   -5.169e-03    6.164e+00
#  Q[111, 3]   -3.366e-01    2.253e-01    5.943e+00   -3.907e-03    5.828e+00
#  Q[114, 0]   -2.257e-01    2.253e-01    4.454e+01   -4.947e-02    4.449e+01
#  Q[114, 1]   -3.213e-01    2.253e-01    5.998e+00   -7.200e-03    5.894e+00
#  Q[114, 2]   -5.971e-01    2.253e-01    6.599e+00   -5.169e-03    6.222e+00
#  Q[114, 3]   -3.070e-01    2.253e-01    5.943e+00   -3.907e-03    5.857e+00
#
# --- Norms ---
# ||grad_task_Q||   = 57.834740
# ||grad_ent_Q||    = 11.010535
# ||grad_col_up_Q|| = 597.857422
# ||grad_col_lo_Q|| = 0.846956
# ||grad_total_Q||  = 602.810364
#
# ============================================================
# FINAL RESULTS
# ============================================================
# Final Q binary gap: 0.459374
# Final colsum error: 1.175380
# Final entropy H(Q): 4.655183
# Final loss: 1.385969
#
# Entries of Q > 0.9:
#   Q[87,1] = 0.999999
#   Q[87,11] = 0.999999
#   Q[87,19] = 0.999999
#   Q[111,0] = 0.999999
#   Q[111,7] = 0.999999
#   Q[111,8] = 0.999999
#   Q[111,16] = 0.999999
#   Q[111,17] = 0.999999
#   Q[113,2] = 0.999999
#   Q[113,8] = 0.999999
#   Q[113,9] = 0.999999
#   Q[113,12] = 0.999999
#   Q[114,15] = 0.999999
#   Q[116,2] = 0.999999
#   Q[116,3] = 0.999999
#   Q[116,14] = 0.999999
#   Q[117,0] = 0.999999
#   Q[117,1] = 0.999999
#   Q[117,4] = 0.999999
#   Q[117,5] = 0.999999
#   Q[117,6] = 0.999999
#   Q[117,11] = 0.999999
#   Q[117,12] = 0.999999
#   Q[117,13] = 0.999999
#   Q[117,14] = 0.999999
#   Q[117,15] = 0.999999
#   Q[117,16] = 0.999999
#   Q[117,17] = 0.999999
#   Q[117,18] = 0.999999
#   Q[117,19] = 0.999999
#   Q[118,4] = 0.999999
#   Q[118,5] = 0.999999
#   Q[118,7] = 0.999999
#   Q[118,10] = 0.999999
